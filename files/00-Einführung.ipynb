# %% [markdown]
# <a href="https://www.matheharry.de/">
#     <img src="../MatheHarry-logos-banner.jpg" width="300" align="center"></a>
#
#
# ---
#
# <h1>MicroPython Grundlagen</h1>
#
#
# ---

# %% [markdown]
# # 0. Quellen und zusätzliche Materialien

# %% [markdown]
# Dieser Kurs beruht zum Teil auf folgenden schon vorhandenen Materialien, die ich ins Deutsche übertragen und/oder an meine Bedürfnisse (Schulstufe 7 & 8) angepasst habe.
#
#
# *   [micro:bit MicroPython Dokumentation](https://microbit-micropython.readthedocs.io/en/latest/)
# *   [UCL’s BBC Micro:bit Tutorials](https://microbit-challenges.readthedocs.io/en/latest/)
# *   [Python for Kids](https://github.com/mytechnotalent/Python-For-Kids) und [MicroPython for micro:bit](https://github.com/mytechnotalent/MicroPython-For-micro-bit) von Kevin Thomas
# *   [MultiWingSpan - BBC micro:bit](http://multiwingspan.co.uk/micro.php)
# *   [Python Tutorial deutsch (Crashkurs)](https://www.youtube.com/playlist?list=PL_pqkvxZ6ho3u8PJAsUU-rOAQ74D0TqZB) auf YouTube
# *   [Whirlwind Tour of Python](https://github.com/jakevdp/WhirlwindTourOfPython) von Jake VanderPlas ([PDF-Version](http://www.oreilly.com/programming/free/files/a-whirlwind-tour-of-python.pdf))
# *   Joseph Santarcangelos [IBM Cognitive Class Jupyter Notebooks](https://github.com/chandrikadeb7/IBM-Cognitiveclass-Python_for_Data_Science).
# *   Samuel L. Watsons interaktiver [Pythonkurs auf Mathigon](https://mathigon.org/course/programming-in-python/introduction?hl=de), der von mir zum Teil ins Deutsche übertragen wurde.
# *   [Python Einführungskurs](https://notebooks.gesis.org/binder/jupyter/user/nilsleiffischer-python-course-m7poiw89/notebooks/index.ipynb) für das Physikalische Anfängerpraktikum der Universität Heidelberg
#
#
# Wer mehr zu Python erfahren möchte: Die Seite [Python-Lernen.de](https://www.python-lernen.de/) bietet alles was ein Programmieranfängerherz begehrt!

# %% [markdown]
# # 1. Einführung

# %% [markdown]
# Python ist eine sehr gute Wahl, egal ob du ein Anfänger bist, der die Grundlagen des Programmierens lernen möchte, oder ein erfahrener Programmierer, der eine große Anwendung entwickeln muss. Die Grundlagen von Python sind leicht zu erlernen und dennoch sind die Möglichkeiten enorm.
#
# Python wurde in den späten 1980er Jahren entwickelt und ist eine für Anfänger und Einsteiger sehr gut geeignete Programmiersprache, die später auch den Fortgeschrittenen und Profis alles bietet, was man sich beim Programmieren wünscht.
#
# ## Python ist einfach
#
# Der Reiz von Python liegt in seiner Einfachheit und Schönheit. Für eine Programmiersprache ist Python relativ übersichtlich, und die Entwickler haben es bewusst so gehalten.
#
# Eine grobe Einschätzung der Komplexität einer Sprache kann man anhand der Anzahl der Schlüsselwörter oder reservierten Wörter in der Sprache ablesen. Dies sind Wörter, die vom Compiler oder Interpreter reserviert sind, weil sie eine bestimmte eingebaute Funktionalität der Sprache bezeichnen.
#
# **Python 3** hat 33 Schlüsselwörter, und **Python 2** hat 31. Im Gegensatz dazu hat **C++** 62, **Java** hat 53 und **Visual Basic** hat mehr als 120.
#
# Python Code hat eine einfache und saubere Struktur, die leicht zu erlernen und leicht zu lesen ist. In der Tat, wie du sehen wirst, erzwingt die Sprachdefinition eine einfach zu lesende Codestruktur.
#
# Das alles sind Gründe, warum Python zB im [PYPL - Index (PopularitY of Programming Language)](https://pypl.github.io/PYPL.html) an erster Stelle gereiht ist.
#
# <a href="https://pypl.github.io/PYPL.html">
#     <img src="https://pypl.github.io/PYPL/All.png" width="400" align="center"></a>

# %% [markdown]
# # 2. Programmierumgebungen

# %% [markdown]
# ## MicroPython Web Editor <a href="https://python.microbit.org/"> <img src="https://python.microbit.org/img/python-logo.svg" width="40" align="center"></a>

# %% [markdown]
# <a href="https://python.microbit.org/v/3">
#     <img src="microbiteditor-header.png" width="600" align="center"></a>
#
# Ein [browserbasierter Code-Editor](https://python.microbit.org/v/beta), der Lehrern und Lernenden hilft, die textbasierte Programmierung auf dem micro:bit optimal zu nutzen. Der Python-Editor ist perfekt für alle, die ihre Coding-Fähigkeiten weiter ausbauen wollen. Eine Auswahl an Snippets und eine Reihe von vorgefertigten Bildern, Sounds und Musik unterstützen dich bei der Programmierung.

# %% [markdown]
# ### Menü
#
# <a align="center">
#     <img src="microbiteditor-menu.png" width="600">
# </a>
#
# Das Hauptmenü des Editors enthält verschiedene Buttons, um deinen Code auf dem micro:bit ausführen zu lassen.
#
# Zuerst musst du den micro:bit mit dem Computer und dem Editor mittels USB-Kabel verbinden. Du findest die Verbindungsschaltfläche, wenn du die 3 Punkte neben dem <kbd>Send to micro:bit</kbd> - Button anklickst und <kbd>Connect</kbd> auswählst.
#
# <a align="center">
#     <img src="microbit-connect.png" width="300">
# </a>
#
# Du wirst dann Schritt für Schritt durch den Verbindungsprozess geführt - beachte die sich öffnenden Fenster mit der Anleitung!
#
# Wenn alles funktioniert hat siehst du folgendes Menü:
#
# <a align="center">
#     <img src="microbit-ready.png" width="300">
# </a>
#
# ---

# %% [markdown]
# <a align="center">
#     <img src="microbiteditor-save.png" width="300">
# </a>
#
# Klicke auf den <kbd>Save</kbd> Button, um deine "hex"-Datei auf dem Computer zu speichern. Über das 3-Punkte-Menü kann auch der Python-Code gespeichert werden.
#
# Mittels <kbd>Open...</kbd> Button kann eine hex- oder Python-Datei hochgeladen und geöffnet werden.
#
# ---

# %% [markdown]
# ### REPL - Serial Konsole
#
# <a align="center">
#     <img src="microbiteditor-serial.png" width="300">
# </a>
#
# Der <kbd>Show Serial</kbd> Button erlaubt es dir, direkt auf dem micro:bit mit MicroPython zu arbeiten, indem du den REPL (*Read, Evaluate, Print Loop*) benutzt.
#
# Wie der Name sagt, handelt es sich dabei um eine dauerhaft ausgeführte Schleife, die folgendermaßen abläuft um den auf der Kommandozeile eingegebenen Python-Code auszuführen:
#
# 1.   Lies die Benutzereingabe
# 2.   Überprüfe den Code
# 3.   Gib das Ergebnis aus
# 4.   Gehe in der Schleife zurück zu Schritt 1
#
# <a align="center">
#     <img src="microbiteditor-repl.png" width="600">
# </a>

# %% [markdown]
# Mittels **REPL** können Befehle also direkt am micro:bit ausgeführt werden. So kann man einfach und schnell mit Code experimentieren und überprüfen, wie gut dieser funktioniert. Man kann die REPL-Konsole auch über das Menü rechts öffnen.

# %% [markdown]
# ### Text-Editor
#
# Im Texteditor schreiben und bearbeiten wir unsere Skripte.

# %% [markdown]
# <a align="center">
#     <img src="microbit-pytheneditor.png" width="600">
# </a>

# %% [markdown]
# Der Texteditor versucht zu helfen, indem er den Text einfärbt, um zu zeigen, was die verschiedenen Teile des Programms sind. Zum Beispiel sind die Python-Schlüsselwörter (Wörter, die in die Python-Sprache eingebaut sind) grau. Die heller gefärbten Wörter sind Teile des Programms, das du erstellt hast. Braune Wörter sind konstante Werte, die sich nie ändern und lila Wörter stellen Zeichenketten dar, die angezeigt werden sollen. Alle Zeilen sind nummeriert, wobei die aktuelle Zeile hervorgehoben ist.
#
# #### Autovervollständigung (Autocomplete)
#
# Die [Autovervollständigung](https://python-editor-2-2-0-beta-5.microbit.org/static/img/autocomplete-1.mp4) gibt dir während der Eingabe Vorschläge für deinen Python-Code, damit du besser verstehst, welche Funktionen dir zur Verfügung stehen. Das ist eine große Hilfe um Tippfehler zu vermeiden und funktionierende Programme zu erstellen.
#
# Drücke die TAB-Taste auf deiner Tastatur, um die aktuelle [Eingabe automatisch zu vervollständigen](https://python-editor-2-2-0-beta-5.microbit.org/static/img/autocomplete-2.mp4).

# %% [markdown]
# ## Mu <a href="https://codewith.mu/en/"> <img src="https://codewith.mu/img/brand.png" width="40" align="center"></a>

# %% [markdown]
# Der Editor Mu richtet sich speziell an Programmieranfänger und war bis vor kurzem noch die komfortabelste Möglichkeit, Pythonprogramme für den micro:bit zu erstellen. Inzwischen ist der Web-Editor in der Beta-Version schon so ausgereift, dass Mu eigentlich nicht mehr benötigt wird.
#
# Da Mu aber über die micro:bit-Programmierung hinausgeht und sogar die Entwicklung einfacher Computerspiele mittels PyGame unterstützt, soll er hier als weiterführende Alternative erwähnt werden.
#
# Eine Beschreibung der Installation und Bedienung [steht hier zur Verfügung](https://docs.google.com/document/d/1U-UTHD-6ji6kDecHd4lGKwDZGI4WQ8nTN7-ju4AIrtI/preview).

# %% [markdown]
# ## Web-Editor von CodeHS  <a href="https://codehs.com/"> <img src="https://static.codehs.com/img/brand_logo.png" width="120" align="center"></a>

# %% [markdown]
# Mit dem  Web-Editor von [CodeHS](https://codehs.com/) können mit zusätzlichen Python-Turtle-Aufgaben grundlegende Konzepte auch ohne micro:bit von zuhause aus auf kindgerechte Weise geübt und gefestigt werden.

# %% [markdown]
# # 3. Beispielcode
#
# Die Code-Beispiele in diesem Jupyter-Notebook können sofort ausgeführt und auch verändert werden.
#
# Nach einer Aufgabe kannst du deine Lösung in einen leeren Code-Block eintippen und damit experimentieren.
#
# Unter dem Codeblock mit deinem Lösungsversuch befindet sich manchmal ein weiterer Codeblock zur automatischen Überprüfung, der so aufgebaut ist:

# %%
# Überprüfe, ob dein Ergebnis richtig ist. Wenn etwas nicht stimmt, erhälst du eine Fehlermeldung mit Hinweisen in der letzten Zeile.
try:
    y
except NameError:
    raise NameError("Es gibt keine Variable 'y'. Weise den Wert einer Variablen mit diesem Namen zu.")
assert y == 10, "Der Wert von y ist falsch. y sollte 10 sein!"
print("👍 Sehr gut!")

# %% [markdown]
# Wenn du nach deiner Lösung diesen Codeblock ausführst, kannst du überprüfen, ob dein Ergebnis richtig ist. Wenn etwas nicht stimmt, erhälst du eine Fehlermeldung mit Hinweisen in der letzten Zeile.

# %% [markdown]
# ---
#
# >> Weiter zu [01-Datentypen](01-Datentypen.ipynb)
